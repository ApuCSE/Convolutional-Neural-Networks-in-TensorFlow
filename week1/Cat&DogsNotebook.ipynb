# %%
# !wget --no-check-certificate \
  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
  -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-03-29 14:41:30--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.126.128, 2a00:1450:4013:c04::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.126.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   110MB/s    in 0.6s
#
# 2020-03-29 14:41:31 (110 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref=zipfile.ZipFile(local_zip,'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/cats_and_dogs_filtered'
train_dir=os.path.join(base_dir, 'train') 
val_dir =os.path.join(base_dir,'validation')

# %%
#directory with training cats/dogs dataset
train_dir_cats=os.path.join(train_dir, 'cats') 
train_dir_dogs=os.path.join(train_dir, 'dogs') 
print(train_dir_cats)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats

# %%
#directory with validation cats/dogs dataset
val_dir_cats = os.path.join(val_dir, 'cats')
val_dir_dogs = os.path.join(val_dir, 'dogs')
print(val_dir_cats)
# Out:
# /tmp/cats_and_dogs_filtered/validation/cats

# %%
train_cat_fnames = os.listdir(train_dir_cats)
train_dog_fnames = os.listdir(train_dir_dogs)

val_cat_fnames = os.listdir(val_dir_cats)
val_dog_fnames = os.listdir(val_dir_dogs)

# %%
os.listdir(base_dir)
# Out:
# ['vectorize.py', 'train', 'validation']

# %%
print(train_cat_fnames[:10])
print(val_dog_fnames[:10])
# Out:
# ['cat.808.jpg', 'cat.41.jpg', 'cat.798.jpg', 'cat.326.jpg', 'cat.773.jpg', 'cat.213.jpg', 'cat.295.jpg', 'cat.305.jpg', 'cat.426.jpg', 'cat.934.jpg']
# ['dog.2035.jpg', 'dog.2254.jpg', 'dog.2207.jpg', 'dog.2457.jpg', 'dog.2158.jpg', 'dog.2428.jpg', 'dog.2472.jpg', 'dog.2109.jpg', 'dog.2491.jpg', 'dog.2431.jpg']

# %%
print('total training cat images :', len(train_cat_fnames))
print('total training dog images :', len(train_dog_fnames))

print('total validation cat images :', len(val_cat_fnames))
print('total validation dog images :', len(val_dog_fnames))
# Out:
# total training cat images : 1000
# total training dog images : 1000
# total validation cat images : 500
# total validation dog images : 500

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows=4
ncols=4

pic_index = 0 #index for iterating for our images

# %%
fig = plt.gcf()

fig.set_size_inches(ncols*4,nrows*4)

# %%
pic_index+=8

next_cat_pix = [os.path.join(train_dir_cats, fname) 
                for fname in train_cat_fnames[ pic_index-8:pic_index] 
               ]
next_dog_pix = [os.path.join(train_dir_dogs, fname) 
                for fname in train_dog_fnames[pic_index-8:pic_index]
                ]
print(next_cat_pix+next_dog_pix)
print(len(next_cat_pix+next_dog_pix))
# Out:
# ['/tmp/cats_and_dogs_filtered/train/cats/cat.808.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.41.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.798.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.326.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.773.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.213.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.295.jpg', '/tmp/cats_and_dogs_filtered/train/cats/cat.305.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.268.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.556.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.493.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.183.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.146.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.689.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.394.jpg', '/tmp/cats_and_dogs_filtered/train/dogs/dog.899.jpg']
# 16

# %%
for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  print(i,'\t',img_path)
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i+1 )
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
# Out:
# 0 	 /tmp/cats_and_dogs_filtered/train/cats/cat.808.jpg
# 1 	 /tmp/cats_and_dogs_filtered/train/cats/cat.41.jpg
# 2 	 /tmp/cats_and_dogs_filtered/train/cats/cat.798.jpg
# 3 	 /tmp/cats_and_dogs_filtered/train/cats/cat.326.jpg
# 4 	 /tmp/cats_and_dogs_filtered/train/cats/cat.773.jpg
# 5 	 /tmp/cats_and_dogs_filtered/train/cats/cat.213.jpg
# 6 	 /tmp/cats_and_dogs_filtered/train/cats/cat.295.jpg
# 7 	 /tmp/cats_and_dogs_filtered/train/cats/cat.305.jpg
# 8 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.268.jpg
# 9 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.556.jpg
# 10 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.493.jpg
# 11 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.183.jpg
# 12 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.146.jpg
# 13 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.689.jpg
# 14 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.394.jpg
# 15 	 /tmp/cats_and_dogs_filtered/train/dogs/dog.899.jpg

# %% [markdown]
# ## ***Defining a MODEL***

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150,150,3)),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
                             tf.keras.layers.MaxPooling2D(2,2),

                             #Flatten the result to feed in the DNN
                             tf.keras.layers.Flatten(),
                             
                             #512 hidden neurons
                             tf.keras.layers.Dense(512, activation='relu'),
                             tf.keras.layers.Dense(1, activation='sigmoid')

])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# ...

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(optimizer=RMSprop(learning_rate=0.001), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# All images will be rescaled by 1./255.
train_datagen = ImageDataGenerator(rescale=1.0/255.)
test_datagen = ImageDataGenerator(rescale=1.0/255.)

# --------------------
# Flow training images in batches of 20 using train_datagen generator
# --------------------
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size = 20,
                                                    class_mode = 'binary',
                                                    target_size = (150, 150))

# --------------------
# Flow validation images in batches of 20 using test_datagen generator
# --------------------
validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        batch_size = 20,
                                                        class_mode = 'binary',
                                                        target_size = (150,150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
print(train_generator)
print(validation_generator)

# %%
history = model.fit_generator(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs = 15,
                    validation_steps = 50,
                    verbose = 2)
# Out:
# Epoch 1/15
# Epoch 1/15
# 100/100 - 9s - loss: 0.8953 - acc: 0.5420 - val_loss: 0.6664 - val_acc: 0.5930
# Epoch 2/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.6671 - acc: 0.6335 - val_loss: 0.6269 - val_acc: 0.6550
# Epoch 3/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.5931 - acc: 0.7060 - val_loss: 0.6330 - val_acc: 0.6770
# Epoch 4/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.4849 - acc: 0.7735 - val_loss: 0.5958 - val_acc: 0.7130
# Epoch 5/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.3938 - acc: 0.8210 - val_loss: 0.7171 - val_acc: 0.6860
# Epoch 6/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.3044 - acc: 0.8720 - val_loss: 0.7294 - val_acc: 0.6940
# Epoch 7/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.2161 - acc: 0.9120 - val_loss: 0.9606 - val_acc: 0.6990
# Epoch 8/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.1433 - acc: 0.9450 - val_loss: 1.0060 - val_acc: 0.6960
# Epoch 9/15
# Epoch 1/15
# 100/100 - 8s - loss: 0.0934 - acc: 0.9695 - val_loss: 1.2884 - val_acc: 0.6800
# Epoch 10/15
# Epoch 1/15
# ...

# %%
import numpy as np

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " is a dog")
    
  else:
    print(fn + " is a cat")
# Out:
#      <input type="file" id="files-a3b45ba9-3269-4643-ae77-d63829bd8b3d" name="files[]" multiple disabled />
#      <output id="result-a3b45ba9-3269-4643-ae77-d63829bd8b3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat1_crop.jpg to cat1_crop (1).jpg
# Saving cat2.png to cat2 (1).png
# Saving cat3_crop.jpeg to cat3_crop (1).jpeg
# Saving dog1_crop.jpg to dog1_crop (1).jpg
# Saving dog2_crop.jpeg to dog2_crop (1).jpeg
# Saving dog3.jpg to dog3 (1).jpg
# [1.]
# cat1_crop.jpg is a dog
# [0.]
# cat2.png is a cat
# [0.]
# cat3_crop.jpeg is a cat
# [1.]
# dog1_crop.jpg is a dog
# [0.]
# dog2_crop.jpeg is a cat
# [1.]
# dog3.jpg is a dog

# %%
model.layers[1:]
#layers.name

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]

#visualization_model = Model(img_input, successive_outputs)
visualization_model = tf.keras.models.Model(inputs = model.input, outputs = successive_outputs)

# Let's prepare a random input image of a cat or dog from the training set.
cat_img_files = [os.path.join(train_dir_cats, f) for f in train_cat_fnames]
dog_img_files = [os.path.join(train_dir_dogs, f) for f in train_dog_fnames]

img_path = random.choice(cat_img_files + dog_img_files)
img = load_img(img_path, target_size=(150, 150))  # this is a PIL image

x   = img_to_array(img)                           # Numpy array with shape (150, 150, 3)
x   = x.reshape((1,) + x.shape)                   # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255.0

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)
#print(successive_feature_maps)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]
print("layer's name:", layer_names)

# -----------------------------------------------------------------------
# Now let's display our representations
# -----------------------------------------------------------------------
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  
  if len(feature_map.shape) == 4:
    
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------

    scale = 20. / n_features
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='viridis' )
# Out:
# layer's name: ['conv2d_6', 'max_pooling2d_6', 'conv2d_7', 'max_pooling2d_7', 'conv2d_8', 'max_pooling2d_8', 'flatten_2', 'dense_4', 'dense_5']
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: RuntimeWarning: invalid value encountered in true_divide

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history['acc']
val_acc  = history.history[ 'val_acc' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
#fig.legend((acc, val_acc),('accuracy','val_accuracy'))
plt.figure()


#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
plt.legend()
# Out:
# No handles with labels found to put in legend.
